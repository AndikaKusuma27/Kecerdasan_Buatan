# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sdnbenbulang03\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sdnbenbulang03\anaconda3\lib\site-packages (from opencv-python) (1.22.4)
# WARNING: Ignoring invalid distribution -illow (c:\users\sdnbenbulang03\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sdnbenbulang03\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sdnbenbulang03\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sdnbenbulang03\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sdnbenbulang03\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\sdnbenbulang03\anaconda3\lib\site-packages)

# %%
import cv2
import matplotlib.pyplot as plt
import time
# %matplotlib inline

def detect_faces(f_cascade, colored_img, scaleFactor = 1.1):
    img_copy = colored_img.copy()
    gray = cv2.cvtColor(img_copy, cv2.COLOR_BGR2GRAY)
    faces = f_cascade.detectMultiScale(gray, scaleFactor=scaleFactor, minNeighbors=5)
    for (x, y, w, h) in faces:
        cv2.rectangle(img_copy, (x, y), (x+w, y+h), (0, 255, 0), 2)
    return img_copy
test2 = cv2.imread('pendekar.jpg')
faces_detected_img = detect_faces(haar_face_cascade, test2)
plt.imshow(convertToRGB(faces_detected_img))
